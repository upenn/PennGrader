# %%
# Generate a UUID

import uuid

import base64

my_uuid = new_occ_id = base64.urlsafe_b64encode(uuid.uuid4().bytes)
my_uuid_2 = new_occ_id = base64.urlsafe_b64encode(uuid.uuid4().bytes)
my_uuid_32 = new_occ_id = my_uuid[0:16] + my_uuid_2[0:16]

print(my_uuid_32)
# Out:
# b'_wKhu9A8QMyG7qmAtMwvBE71SGC_NH8K'

# %%
# Now copy this into DynamoDB as the secret_key and add a course_id which is a string name!

# TODO: Python connect to DynamoDB using IAM access codes, write this directly
# so it's all programmatic
# Out:
# 32
